# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("C:\\Users\\RAHUL\\Downloads\\archive\\Loan_Default.csv")
data
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0        24890  2019         cf  Sex Not Available         nopre     type1
# 1        24891  2019         cf               Male         nopre     type2
# 2        24892  2019         cf               Male           pre     type1
# 3        24893  2019         cf               Male         nopre     type1
# 4        24894  2019         cf              Joint           pre     type1
# ...        ...   ...        ...                ...           ...       ...
# 148665  173555  2019         cf  Sex Not Available         nopre     type1
# 148666  173556  2019         cf               Male         nopre     type1
# 148667  173557  2019         cf               Male         nopre     type1
# 148668  173558  2019         cf             Female         nopre     type1
# 148669  173559  2019         cf             Female         nopre     type1
#
# ...

# %%
df = pd.read_csv("C:\\Users\\RAHUL\\Downloads\\archive\\Loan_Default.csv")

df.head()
# Out:
#       ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0  24890  2019         cf  Sex Not Available         nopre     type1
# 1  24891  2019         cf               Male         nopre     type2
# 2  24892  2019         cf               Male           pre     type1
# 3  24893  2019         cf               Male         nopre     type1
# 4  24894  2019         cf              Joint           pre     type1
#
#   loan_purpose Credit_Worthiness open_credit business_or_commercial  ...  \
# 0           p1                l1        nopc                  nob/c  ...
# 1           p1                l1        nopc                    b/c  ...
# 2           p1                l1        nopc                  nob/c  ...
# 3           p4                l1        nopc                  nob/c  ...
# 4           p1                l1        nopc                  nob/c  ...
#
#    credit_type  Credit_Score  co-applicant_credit_type    age  \
# ...

# %%
df.shape
# Out:
# (148670, 34)

# %%
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of rows: 148670
# Number of columns: 34

# %%
df.columns.tolist()
# Out:
# ['ID',
#  'year',
#  'loan_limit',
#  'Gender',
#  'approv_in_adv',
#  'loan_type',
#  'loan_purpose',
#  'Credit_Worthiness',
#  'open_credit',
#  'business_or_commercial',
#  'loan_amount',
#  'rate_of_interest',
#  'Interest_rate_spread',
#  'Upfront_charges',
#  'term',
#  'Neg_ammortization',
#  'interest_only',
#  'lump_sum_payment',
#  'property_value',
#  'construction_type',
#  'occupancy_type',
#  'Secured_by',
#  'total_units',
#  'income',
#  'credit_type',
#  'Credit_Score',
#  'co-applicant_credit_type',
#  'age',
#  'submission_of_application',
#  'LTV',
#  'Region',
#  'Security_Type',
#  'Status',
#  'dtir1']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148670 entries, 0 to 148669
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   ID                         148670 non-null  int64
#  1   year                       148670 non-null  int64
#  2   loan_limit                 145326 non-null  object
#  3   Gender                     148670 non-null  object
#  4   approv_in_adv              147762 non-null  object
#  5   loan_type                  148670 non-null  object
#  6   loan_purpose               148536 non-null  object
#  7   Credit_Worthiness          148670 non-null  object
#  8   open_credit                148670 non-null  object
#  9   business_or_commercial     148670 non-null  object
#  10  loan_amount                148670 non-null  int64
#  11  rate_of_interest           112231 non-null  float64
#  12  Interest_rate_spread       112031 non-null  float64
# ...

# %%
df.describe()
# Out:
#                   ID      year   loan_amount  rate_of_interest  \
# count  148670.000000  148670.0  1.486700e+05     112231.000000
# mean    99224.500000    2019.0  3.311177e+05          4.045476
# std     42917.476598       0.0  1.839093e+05          0.561391
# min     24890.000000    2019.0  1.650000e+04          0.000000
# 25%     62057.250000    2019.0  1.965000e+05          3.625000
# 50%     99224.500000    2019.0  2.965000e+05          3.990000
# 75%    136391.750000    2019.0  4.365000e+05          4.375000
# max    173559.000000    2019.0  3.576500e+06          8.000000
#
#        Interest_rate_spread  Upfront_charges           term  property_value  \
# count         112031.000000    109028.000000  148629.000000    1.335720e+05
# mean               0.441656      3224.996127     335.136582    4.978935e+05
# std                0.513043      3251.121510      58.409084    3.599353e+05
# min               -3.638000         0.000000      96.000000    8.000000e+03
# ...

# %%
missing=df.isnull().sum()
print(missing)
# Out:
# ID                               0
# year                             0
# loan_limit                    3344
# Gender                           0
# approv_in_adv                  908
# loan_type                        0
# loan_purpose                   134
# Credit_Worthiness                0
# open_credit                      0
# business_or_commercial           0
# loan_amount                      0
# rate_of_interest             36439
# Interest_rate_spread         36639
# Upfront_charges              39642
# term                            41
# Neg_ammortization              121
# interest_only                    0
# lump_sum_payment                 0
# property_value               15098
# construction_type                0
# occupancy_type                   0
# Secured_by                       0
# total_units                      0
# income                        9150
# credit_type                      0
# Credit_Score                     0
# co-applicant_credit_type         0
# ...

# %%
df["Status"].value_counts()
# Out:
# Status
# 0    112031
# 1     36639
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 5))

ax = sns.countplot(data=df, x="Status")

plt.title("Loan Status Distribution", fontsize=16)
plt.xlabel("Loan Status", fontsize=12)
plt.ylabel("Number of Applications", fontsize=12)

for container in ax.containers:
    ax.bar_label(container)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df,x="Credit_Score",bins=30,kde=True)
plt.title("Distributionof Credit Scores")
plt.xlabel("Credit Scores")
plt.ylabel("Number of Applicants")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df,x="Status",y="Credit_Score")
plt.title("Credit Score vs Loan status")
plt.xlabel("Loan status")
plt.ylabel("Credit Score")
plt.show()

# %%
df["loan_purpose"].value_counts()
# Out:
# loan_purpose
# p3    55934
# p4    54799
# p1    34529
# p2     3274
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df,x="loan_purpose")
plt.title("Loans applications by purpose")
plt.xlabel("Loan Purpose")
plt.ylabel("No. of applications")
plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.countplot(
    data=df,
    x="loan_type"
)

plt.title("Loan Applications by Loan Type")
plt.xlabel("Loan Type")
plt.ylabel("Number of Applications")

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.countplot(
    data=df,
    x="Region"
)

plt.title("Loan Applications by Region")
plt.xlabel("Region")
plt.ylabel("Number of Applications")

plt.show()

# %%
missing = df.isnull().sum()
missing_percent = (df.isnull().sum() / len(df)) * 100

missing_table = pd.DataFrame({
    "Missing Values": missing,
    "Missing Percentage": missing_percent
})

missing_table = missing_table[
    missing_table["Missing Values"] > 0
].sort_values("Missing Percentage", ascending=False)

missing_table
# Out:
#                            Missing Values  Missing Percentage
# Upfront_charges                     39642           26.664425
# Interest_rate_spread                36639           24.644515
# rate_of_interest                    36439           24.509989
# dtir1                               24121           16.224524
# property_value                      15098           10.155378
# LTV                                 15098           10.155378
# income                               9150            6.154571
# loan_limit                           3344            2.249277
# approv_in_adv                         908            0.610749
# age                                   200            0.134526
# submission_of_application             200            0.134526
# loan_purpose                          134            0.090133
# Neg_ammortization                     121            0.081388
# term                                   41            0.027578

# %%
print("Number of duplicate rows:",df.duplicated().sum())
# Out:
# Number of duplicate rows: 0

# %%
categorical_columns = df.select_dtypes(include="object").columns

for column in categorical_columns:
    print("\n", column)
    print(df[column].value_counts().head(10))
# Out:
#  loan_limit
# loan_limit
# cf     135348
# ncf      9978
# Name: count, dtype: int64
#
#  Gender
# Gender
# Male                 42346
# Joint                41399
# Sex Not Available    37659
# Female               27266
# Name: count, dtype: int64
#
#  approv_in_adv
# approv_in_adv
# nopre    124621
# pre       23141
# Name: count, dtype: int64
#
#  loan_type
# loan_type
# type1    113173
# type2     20762
# type3     14735
# Name: count, dtype: int64
#
#  loan_purpose
# loan_purpose
# p3    55934
# p4    54799
# p1    34529
# p2     3274
# Name: count, dtype: int64
#
#  Credit_Worthiness
# Credit_Worthiness
# l1    142344
# l2      6326
# Name: count, dtype: int64
#
#  open_credit
# open_credit
# nopc    148114
# opc        556
# Name: count, dtype: int64
#
#  business_or_commercial
# business_or_commercial
# nob/c    127908
# b/c       20762
# Name: count, dtype: int64
#
#  Neg_ammortization
# Neg_ammortization
# not_neg    133420
# neg_amm     15129
# Name: count, dtype: int64
# ...

# %%
numeric_columns = df.select_dtypes(include=np.number).columns

print(numeric_columns.tolist())
# Out:
# ['ID', 'year', 'loan_amount', 'rate_of_interest', 'Interest_rate_spread', 'Upfront_charges', 'term', 'property_value', 'income', 'Credit_Score', 'LTV', 'Status', 'dtir1']

# %%
df[numeric_columns].describe().T
# Out:
#                          count           mean            std           min  \
# ID                    148670.0   99224.500000   42917.476598  24890.000000
# year                  148670.0    2019.000000       0.000000   2019.000000
# loan_amount           148670.0  331117.743997  183909.310127  16500.000000
# rate_of_interest      112231.0       4.045476       0.561391      0.000000
# Interest_rate_spread  112031.0       0.441656       0.513043     -3.638000
# Upfront_charges       109028.0    3224.996127    3251.121510      0.000000
# term                  148629.0     335.136582      58.409084     96.000000
# property_value        133572.0  497893.465696  359935.315562   8000.000000
# income                139520.0    6957.338876    6496.586382      0.000000
# Credit_Score          148670.0     699.789103     115.875857    500.000000
# LTV                   133572.0      72.746457      39.967603      0.967478
# ...

# %%
print(df["Status"].value_counts())
# Out:
# Status
# 0    112031
# 1     36639
# Name: count, dtype: int64

# %%
print(df["Status"].value_counts(normalize=True) * 100)
# Out:
# Status
# 0    75.355485
# 1    24.644515
# Name: proportion, dtype: float64

# %%
print(df["Status"].value_counts())
# Out:
# Status
# 0    112031
# 1     36639
# Name: count, dtype: int64

# %%
default_rate = (df["Status"] == 1).mean() * 100

print(f"Default Rate: {default_rate:.2f}%")
# Out:
# Default Rate: 24.64%

# %%
loan_type_counts = df["loan_type"].value_counts()

plt.figure(figsize=(7, 7))

plt.pie(
    loan_type_counts,
    labels=loan_type_counts.index,
    autopct="%1.1f%%",
    startangle=90
)

plt.title("Distribution of Loan Types")

plt.show()

# %%
df["loan_type"].value_counts()
# Out:
# loan_type
# type1    113173
# type2     20762
# type3     14735
# Name: count, dtype: int64

# %%
gender_default = df.groupby("Gender")["Status"].mean() * 100

print(gender_default)
# Out:
# Gender
# Female               25.115528
# Joint                19.162299
# Male                 26.191376
# Sex Not Available    28.590775
# Name: Status, dtype: float64

# %%
plt.figure(figsize=(9, 5))

gender_default.sort_values(ascending=False).plot(kind="bar")

plt.title("Default Rate by Gender")
plt.xlabel("Gender")
plt.ylabel("Default Rate (%)")
plt.xticks(rotation=0)

plt.tight_layout()
plt.show()

# %%
purpose_default = (
    df.groupby("loan_purpose")["Status"]
    .mean()
    .sort_values(ascending=False)
    * 100
)

print(purpose_default)
# Out:
# loan_purpose
# p2    33.078803
# p1    25.876799
# p3    25.022348
# p4    22.974872
# Name: Status, dtype: float64

# %%
plt.figure(figsize=(10, 6))

purpose_default.plot(kind="bar")

plt.title("Default Rate by Loan Purpose")
plt.xlabel("Loan Purpose")
plt.ylabel("Default Rate (%)")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=df,
    x="Credit_Score",
    y="LTV",
    hue="Status",
    alpha=0.5
)

plt.title("Credit Score vs Loan-to-Value (LTV)")
plt.xlabel("Credit Score")
plt.ylabel("LTV")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(9,6))
sns.violinplot(data=df,x="Status",y="Credit_Score")
plt.title("Credit Score distribution by loan status")
plt.xlabel("Loan status")
plt.ylabel("Credit score")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.kdeplot(
    data=df,
    x="LTV",
    fill=True)

plt.title("Distribution of Loan-to-Value (LTV)")
plt.xlabel("LTV")
plt.ylabel("Density")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.regplot(
    data=df.sample(min(5000, len(df))),
    x="Credit_Score",
    y="LTV",
    scatter_kws={"alpha": 0.3},
    line_kws={}
)

plt.title("Relationship Between Credit Score and LTV")
plt.xlabel("Credit Score")
plt.ylabel("LTV")

plt.tight_layout()
plt.show()

# %%
region_default = (
    df.groupby("Region")["Status"]
    .mean()
    .sort_values(ascending=False)
    * 100
)

print(region_default)
# Out:
# Region
# North-East    30.445344
# central       27.538232
# south         26.629280
# North         22.511442
# Name: Status, dtype: float64

# %%
plt.figure(figsize=(8, 5))

region_default.plot(kind="bar")

plt.title("Default Rate by Region")
plt.xlabel("Region")
plt.ylabel("Default Rate (%)")
plt.xticks(rotation=0)

plt.tight_layout()
plt.show()

# %%
yearly_default = df.groupby("year")["Status"].mean() * 100

print(yearly_default)
# Out:
# year
# 2019    24.644515
# Name: Status, dtype: float64

# %%
numeric_df = df.select_dtypes(include=np.number)

correlation = numeric_df.corr()

plt.figure(figsize=(14, 10))

sns.heatmap(
    correlation,
    annot=True,
    fmt=".2f",
    cmap="coolwarm"
)

plt.title("Correlation Between Numerical Variables")

plt.tight_layout()
plt.show()

# %%
df_clean = df.copy()

# %%
print("Duplicates:", df_clean.duplicated().sum())
# Out:
# Duplicates: 0

# %%
df_clean = df_clean.drop_duplicates()

# %%
missing_percentage = (
    df_clean.isnull().mean() * 100
).sort_values(ascending=False)

missing_percentage[missing_percentage > 0]
# Out:
# Upfront_charges              26.664425
# Interest_rate_spread         24.644515
# rate_of_interest             24.509989
# dtir1                        16.224524
# LTV                          10.155378
# property_value               10.155378
# income                        6.154571
# loan_limit                    2.249277
# approv_in_adv                 0.610749
# submission_of_application     0.134526
# age                           0.134526
# loan_purpose                  0.090133
# Neg_ammortization             0.081388
# term                          0.027578
# dtype: float64

# %%
df_clean["Credit_Score_Group"] = pd.cut(
    df_clean["Credit_Score"],
    bins=[0, 599, 699, 799, 900],
    labels=["Below 600", "600-699", "700-799", "800+"]
)

# %%
credit_default = (
    df_clean.groupby("Credit_Score_Group", observed=True)["Status"]
    .mean() * 100
)

print(credit_default)
# Out:
# Credit_Score_Group
# Below 600    24.630277
# 600-699      24.483871
# 700-799      24.286219
# 800+         25.170141
# Name: Status, dtype: float64

# %%
plt.figure(figsize=(9, 5))

credit_default.plot(kind="bar")

plt.title("Default Rate by Credit Score Group")
plt.xlabel("Credit Score Group")
plt.ylabel("Default Rate (%)")
plt.xticks(rotation=0)

plt.tight_layout()
plt.show()

# %%
important_columns = [
    "Credit_Score",
    "LTV",
    "dtir1",
    "Status",
    "loan_type",
    "loan_purpose",
    "Gender",
    "Region",
    "income",
    "loan_amount",
    "property_value",
    "age"
]

df_clean[important_columns].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148670 entries, 0 to 148669
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Credit_Score    148670 non-null  int64
#  1   LTV             133572 non-null  float64
#  2   dtir1           124549 non-null  float64
#  3   Status          148670 non-null  int64
#  4   loan_type       148670 non-null  object
#  5   loan_purpose    148536 non-null  object
#  6   Gender          148670 non-null  object
#  7   Region          148670 non-null  object
#  8   income          139520 non-null  float64
#  9   loan_amount     148670 non-null  int64
#  10  property_value  133572 non-null  float64
#  11  age             148470 non-null  object
# dtypes: float64(4), int64(3), object(5)
# memory usage: 13.6+ MB

# %%
important_columns = [
    "Credit_Score",
    "LTV",
    "dtir1",
    "Status",
    "loan_type",
    "loan_purpose",
    "Gender",
    "Region",
    "income",
    "loan_amount",
    "property_value",
    "age"
]

df_clean[important_columns].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148670 entries, 0 to 148669
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Credit_Score    148670 non-null  int64
#  1   LTV             133572 non-null  float64
#  2   dtir1           124549 non-null  float64
#  3   Status          148670 non-null  int64
#  4   loan_type       148670 non-null  object
#  5   loan_purpose    148536 non-null  object
#  6   Gender          148670 non-null  object
#  7   Region          148670 non-null  object
#  8   income          139520 non-null  float64
#  9   loan_amount     148670 non-null  int64
#  10  property_value  133572 non-null  float64
#  11  age             148470 non-null  object
# dtypes: float64(4), int64(3), object(5)
# memory usage: 13.6+ MB

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=df_clean.sample(min(5000, len(df_clean))),
    x="property_value",
    y="loan_amount",
    alpha=0.4
)

plt.title("Property Value vs Loan Amount")
plt.xlabel("Property Value")
plt.ylabel("Loan Amount")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.histplot(
    data=df_clean,
    x="LTV",
    bins=40,
    kde=True
)

plt.title("Distribution of Loan-to-Value (LTV)")
plt.xlabel("LTV (%)")
plt.ylabel("Number of Applications")

plt.tight_layout()
plt.show()

# %%
df_clean["LTV_Group"] = pd.cut(
    df_clean["LTV"],
    bins=[0, 60, 70, 80, 90, 100, np.inf],
    labels=[
        "≤60%",
        "61–70%",
        "71–80%",
        "81–90%",
        "91–100%",
        ">100%"
    ]
)

# %%
ltv_default = (
    df_clean.groupby("LTV_Group", observed=True)["Status"]
    .mean() * 100
)

print(ltv_default)
# Out:
# LTV_Group
# ≤60%       13.922923
# 61–70%     12.497479
# 71–80%     13.230646
# 81–90%     18.437655
# 91–100%    19.689119
# >100%      65.091718
# Name: Status, dtype: float64

# %%
plt.figure(figsize=(10, 6))

ltv_default.plot(kind="bar")

plt.title("Default Rate by LTV Group")
plt.xlabel("LTV Group")
plt.ylabel("Default Rate (%)")
plt.xticks(rotation=0)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.histplot(
    data=df_clean,
    x="dtir1",
    bins=30,
    kde=True
)

plt.title("Distribution of Debt-to-Income Ratio")
plt.xlabel("DTIR")
plt.ylabel("Number of Applicants")

plt.tight_layout()
plt.show()

# %%
print("Status values:")
print(df_clean["Status"].value_counts(dropna=False))

print("\nMissing Status values:")
print(df_clean["Status"].isna().sum())
# Out:
# Status values:
# Status
# 0    112031
# 1     36639
# Name: count, dtype: int64
#
# Missing Status values:
# 0

# %%
X = df_clean.drop(columns=["Status"])
y = df_clean["Status"]

print("Features:", X.shape)
print("Target:", y.shape)
# Out:
# Features: (148670, 36)
# Target: (148670,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training data:", X_train.shape)
print("Testing data:", X_test.shape)
# Out:
# Training data: (118936, 36)
# Testing data: (29734, 36)

# %%
df_clean.to_csv("DEFAULTER_PROJECT.csv", index=False)

print("Cleaned dataset saved successfully!")
# Out:
# Cleaned dataset saved successfully!
